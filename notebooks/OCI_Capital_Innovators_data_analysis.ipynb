# %%
import sys; sys.executable
# Out:
# 'C:\\Users\\thandus\\Anaconda3\\python.exe'

# %%
sys.version
# Out:
# '3.5.2 |Anaconda custom (64-bit)| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]'

# %%
import pandas as pd
df = pd.read_csv('cap_innov_data_sp16.csv')

# %%
df.head()
# Out:
#    ﻿"Application ID"      Date Created    Date Finalized Team or Person  \
# 0             162763  11/26/2014 16:30  11/26/2014 17:47         Person
# 1             162514  11/25/2014 16:37  11/25/2014 16:53           Team
# 2             162359  11/25/2014 10:13                           Person
# 3             162314  11/25/2014 05:16  11/26/2014 01:36           Team
# 4             162264  11/24/2014 23:35  11/25/2014 01:14           Team
#
#            Name  User ID  Followers         City        Country  \
# 0  nunzio guida   203578          0       Torino          Italy
# 1     Remini.me   282683          1     Tel Aviv         Israel
# 2   Saurabh Bag   127060          1         Pune          India
# 3      Brighten   203381          3  Los Angeles  United States
# 4        Xooker   375581          0    Lexington  United States
#
#                                    Brief Description  \
# 0     creating is faboulous, innovating is strategic
# ...

# %%
df.tail()
# Out:
#      ﻿"Application ID"      Date Created    Date Finalized Team or Person  \
# 152             147123  10/02/2014 19:15  10/02/2014 19:53           Team
# 153             147003  10/02/2014 13:08                           Person
# 154             146907  10/02/2014 04:22                           Person
# 155             146903  10/02/2014 03:40  11/18/2014 13:43           Team
# 156             146862  10/01/2014 21:27  10/01/2014 21:50         Person
#
#                 Name  User ID  Followers           City        Country  \
# 152         benjamin   252621          0  Mountain View  United States
# 153       Mark Repko    70592          3   Indianapolis  United States
# 154  Anthony Alvarez   384228          0    Saint Louis  United States
# 155      Gapedia-com   264529         10         Dallas  United States
# 156     Nanci Kavich   317600          0          Omaha  United States
#
#                                      Brief Description  \
# ...

# %%
df.columns
# Out:
# Index(['﻿"Application ID"', 'Date Created', 'Date Finalized', 'Team or Person',
#        'Name', 'User ID', 'Followers', 'City', 'Country', 'Brief Description',
#        ...
#        'Evaluator 5 Name', 'Evaluator 5 Rating', 'Evaluator 5 Comments',
#        'Evaluator 6 Name', 'Evaluator 6 Rating', 'Evaluator 6 Comments',
#        'Evaluator 7 Name', 'Evaluator 7 Rating', 'Evaluator 7 Comments',
#        'Tags'],
#       dtype='object', length=238)
